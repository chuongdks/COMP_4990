# %%
import pandas as pd

# Step 1: Load the data
df = pd.read_csv('./QueryResults100.csv')

# Step 2: Filter only the Initial Title, Body, Tags
filter = df['Name'].isin(['Initial Title', 'Initial Body', 'Initial Tags'])
df = df[filter]

# Step 3: Group by PostId
grouped = df.groupby('PostId')

# # Debug: Display the dataframe after group by PostID object
# for post_id, group in grouped:
#     print(f"Post ID: {post_id}")
#     print(group)
#     print("-" * 40)
    
# Step 4: For each PostId, extract Title, Body, and Tags
records = []

for post_id, group in grouped:
    # Dictionary to hold one post
    post = {'PostId': post_id}
    
    for row in group.itertuples():
        if row.Name == 'Initial Title':
            post['Title'] = row.Text
        elif row.Name == 'Initial Body':
            post['Body'] = row.Text
        elif row.Name == 'Initial Tags':
            post['Tags'] = row.Text
    
    records.append(post)
    
# print(records)

# Step 5: Turn records List into DataFrame
final_df = pd.DataFrame(records)

# Step 6: Display final dataframe
# print(final_df)
from IPython.display import display
display(final_df)

# Step 7: Export to csv file
final_df.to_csv(path_or_buf='./PostHistoryFirstVersion.csv',
          index = False) # False index param means no index for export data
# Out:
#       PostId                                              Title  \
# 0     709368  WPF 3D - Detirmine whether a ModelVisual3D is ...
# 1    1637981               Resources for SharePoint Development
# 2    1971732                How to "git show" on a remote repo?
# 3    2074235  Where to put a ViewModel factory in my ASP.NET...
# 4    2213312  How to change cursor for the whole document (n...
# ..       ...                                                ...
# 95  76479964  How to go back to previous screen while using ...
# 96  77445914  dask import errors, dataframe/client - version...
# 97  77929999    How to generate name combinations with initials
# 98  78907548         Trying to optimize my ARPLS implementation
# 99  79451235        Multiple cursors follow mouse in Javascript
#
#                                                  Body  \
# 0   I have a cube rendering inside a `Viewport3D` ...
# 1   I have to develop an appliction (Asp.Net - may...
# 2   I'm trying to hook my git repository with Micr...
# 3   I have a fairly complicated ViewModel associat...
# 4                      In the way it's cross-browser.
# ..                                                ...
# 95  I am using error boundary in react native and ...
# 96  Not all versions of `dask.dataframe` and `pand...
# 97  Given a string of a person's name:\r\n```\r\n"...
# 98  I'm trying to optimize my spectral baseline fi...
# 99  I have a grid with multiple items. Each item h...
#
#                                                  Tags
# 0                <wpd><3d><modelvisual3d><viewport3d>
# 1                                        <sharepoint>
# 2                                               <git>
# 3                                       <asp.net-mvc>
# 4                                        <javascript>
# ..                                                ...
# 95            <react-native><react-native-navigation>
# 96             <python><pandas><dask><dask-dataframe>
# 97                                           <python>
# 98   <python><numpy><optimization><scipy><statistics>
# 99  <javascript><addeventlistener><mousemove><mous...
#
# [100 rows x 4 columns]
